# %% [markdown]
# <a href="https://colab.research.google.com/github/One1Tick/nuclear/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colabcode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 KB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.3/761.3 KB 49.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 79.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.0/347.0 KB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 424.0/424.0 KB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.2/273.2 KB 28.0 MB/s eta 0:00:00
# ...

# %%
from colabcode import ColabCode
ColabCode(port=9999)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://6bb0-35-222-11-28.ngrok.io" -> "http://localhost:9999"
# [2023-01-13T18:30:32.663Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2023-01-13T18:30:32.664Z] info  Using user-data-dir ~/.local/share/code-server
# [2023-01-13T18:30:32.682Z] info  Using config file ~/.config/code-server/config.yaml
# [2023-01-13T18:30:32.682Z] info  HTTP server listening on http://127.0.0.1:9999
# [2023-01-13T18:30:32.682Z] info    - Authentication is disabled
# [2023-01-13T18:30:32.682Z] info    - Not serving HTTPS
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
